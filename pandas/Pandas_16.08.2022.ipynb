# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['new_col'] = 'titanic'
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S  titanic
# 1      0          PC 17599  71.2833   C85        C  titanic
# 2      0  STON/O2. 3101282   7.9250   NaN        S  titanic
# 3      0            113803  53.1000  C123        S  titanic
# ...

# %%
df['new_col2'] = df['PassengerId'].apply(lambda x: x+10)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S  titanic        11
# 1      0          PC 17599  71.2833   C85        C  titanic        12
# 2      0  STON/O2. 3101282   7.9250   NaN        S  titanic        13
# ...

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df['Cabin'].head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
df['Cabin'].isnull().head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Cabin, dtype: bool

# %%
# out of 891 rows 687 rows have missing value - 204 non null values
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# new_col          0
# new_col2         0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S  titanic        11
# 1      0          PC 17599  71.2833   C85        C  titanic        12
# 2      0  STON/O2. 3101282   7.9250   NaN        S  titanic        13
# ...

# %%
df.sort_values(by=['Name'], ascending=True).head()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#         Sex   Age  SibSp  Parch     Ticket   Fare Cabin Embarked  new_col  \
# 845    male  42.0      0      0  C.A. 5547   7.55   NaN        S  titanic
# 746    male  16.0      1      1  C.A. 2673  20.25   NaN        S  titanic
# 279  female  35.0      1      1  C.A. 2673  20.25   NaN        S  titanic
# 308    male  30.0      1      0  P/PP 3381  24.00   NaN        C  titanic
# 874  female  28.0      1      0  P/PP 3381  24.00   NaN        C  titanic
#
#      new_col2
# 845       856
# 746       757
# 279       290
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col', 'new_col2'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# new_col         object
# new_col2         int64
# dtype: object

# %%
#Create 2 lists such that num_columns: contains names of columns not string / cat_columns: contains names of columns which are string
num_columns = [column for column in df.columns if df[column].dtypes != object]
print(num_columns)
cat_columns = [column for column in df.columns if df[column].dtypes == object]
print(cat_columns)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'new_col2']
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'new_col']

# %%
df.dtypes[df.dtypes == object].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'new_col'], dtype='object')

# %%
df.dtypes[df.dtypes != object].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare',
#        'new_col2'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S  titanic        11
# 1      0          PC 17599  71.2833   C85        C  titanic        12
# 2      0  STON/O2. 3101282   7.9250   NaN        S  titanic        13
# ...

# %%
#mean, median and mode
df['Age'].median()
# Out:
# 28.0

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df['Sex'].value_counts().index[0]
# Out:
# 'male'

# %%
df['Sex'].mode()
# Out:
# 0    male
# Name: Sex, dtype: object

# %%
df['new_col2'] = df['Age'].diff()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S  titanic       NaN
# 1      0          PC 17599  71.2833   C85        C  titanic      16.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  titanic     -12.0
# ...

# %%
# describe
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare    new_col2
# count  891.000000  891.000000  562.000000
# mean     0.381594   32.204208   -0.367883
# std      0.806057   49.693429   19.995974
# min      0.000000    0.000000  -65.000000
# 25%      0.000000    7.910400  -13.000000
# 50%      0.000000   14.454200   -1.000000
# 75%      0.000000   31.000000   13.000000
# ...

# %%
df['Sex'].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
df[cat_columns].describe().transpose()
# Out:
#          count unique                      top freq
# Name       891    891  Braund, Mr. Owen Harris    1
# Sex        891      2                     male  577
# Ticket     891    681                   347082    7
# Cabin      204    147                  B96 B98    4
# Embarked   889      3                        S  644
# new_col    891      1                  titanic  891

# %%
df[cat_columns].describe().T
# Out:
#          count unique                      top freq
# Name       891    891  Braund, Mr. Owen Harris    1
# Sex        891      2                     male  577
# Ticket     891    681                   347082    7
# Cabin      204    147                  B96 B98    4
# Embarked   889      3                        S  644
# new_col    891      1                  titanic  891

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# 10,20,30,40,50,60,70,300

# -10,10,20,30,40,50,60,70,300

# Q1 - 25th percentile
# Q2 - 50th percentile / Median
# Q3 - 7th percentile

# Inter quartile range IQR = Q3-Q1

# %%
# is mean impacted by outliers?
# 10,20,30,40,50,60,70 = 100/5 = 20
# 10,20,30,40,50,60,70 = 100+300/5+1 = 400/6 =

# %%
# is median impacted by outliers ?
# 10,20,30,40,50,60,70 - Step1: sort the values Step2:
# 10,20,30,40,050,60,70,3000000000

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S  titanic       NaN
# 1      0          PC 17599  71.2833   C85        C  titanic      16.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  titanic     -12.0
# ...

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Group by
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ...  Fare           new_col2            \
#             max  count      mean  ...   75%       max    count      mean
# Survived                          ...
# 0         891.0  549.0  2.531876  ...  26.0  263.0000    335.0  0.753224
# 1         890.0  342.0  1.950292  ...  57.0  512.3292    227.0 -2.022379
#
#
#                 std   min   25%  50%   75%   max
# Survived
# 0         19.802306 -65.0 -11.0  1.0  12.5  70.0
# 1         20.208577 -54.0 -15.0 -3.0  13.0  54.0
#
# [2 rows x 56 columns]

# %%
df.groupby('Survived').describe().columns
# Out:
# MultiIndex([('PassengerId', 'count'),
#             ('PassengerId',  'mean'),
#             ('PassengerId',   'std'),
#             ('PassengerId',   'min'),
#             ('PassengerId',   '25%'),
#             ('PassengerId',   '50%'),
#             ('PassengerId',   '75%'),
#             ('PassengerId',   'max'),
#             (     'Pclass', 'count'),
#             (     'Pclass',  'mean'),
#             (     'Pclass',   'std'),
#             (     'Pclass',   'min'),
#             (     'Pclass',   '25%'),
#             (     'Pclass',   '50%'),
#             (     'Pclass',   '75%'),
#             (     'Pclass',   'max'),
#             (        'Age', 'count'),
#             (        'Age',  'mean'),
#             (        'Age',   'std'),
#             (        'Age',   'min'),
#             (        'Age',   '25%'),
#             (        'Age',   '50%'),
#             (        'Age',   '75%'),
#             (        'Age',   'max'),
#             (      'SibSp', 'count'),
# ...

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
df.groupby('Survived').describe()['Pclass']
# Out:
#           count      mean       std  min  25%  50%  75%  max
# Survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0
# 1         342.0  1.950292  0.863321  1.0  1.0  2.0  3.0  3.0

# %%
df.groupby('Embarked').describe()['PassengerId'].transpose()
# Out:
# Embarked           C           Q           S
# count     168.000000   77.000000  644.000000
# mean      445.357143  417.896104  449.527950
# std       259.454201  253.646282  256.942044
# min         2.000000    6.000000    1.000000
# 25%       235.500000  209.000000  225.750000
# 50%       455.000000  389.000000  447.500000
# 75%       651.000000  630.000000  673.250000
# max       890.000000  891.000000  889.000000

# %%
df.groupby(['Survived', 'Embarked'])['PassengerId'].count()
# Out:
# Survived  Embarked
# 0         C            75
#           Q            47
#           S           427
# 1         C            93
#           Q            30
#           S           217
# Name: PassengerId, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked  new_col  new_col2
# Survived
# 0            68       549      549       335
# 1           136       340      342       227

# %%
df.groupby('Survived').max()
# Out:
# /var/folders/8c/xhhzc929045973qqkytbdr6h0000gn/T/ipykernel_5257/123491824.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Survived').max()
#           PassengerId  Pclass                         Name   Sex   Age  SibSp  \
# Survived
# 0                 891       3  van Melkebeke, Mr. Philemon  male  74.0      8
# 1                 890       3      de Mulder, Mr. Theodore  male  80.0      4
#
#           Parch     Ticket      Fare  new_col  new_col2
# Survived
# 0             6  WE/P 5735  263.0000  titanic      70.0
# 1             5  WE/P 5735  512.3292  titanic      54.0

# %%
# dataframe.groupby(['Survived', ..]).aggregate function()
# aggregrate functions
#min(), max(), count(), avg(), median(), mean(), mode(), describe()

# %%
df[num_columns].groupby(['Pclass']).median()
# Out:
#         PassengerId  Survived   Age  SibSp  Parch     Fare  new_col2
# Pclass
# 1             472.0       1.0  37.0    0.0    0.0  60.2875       9.0
# 2             435.5       0.0  29.0    0.0    0.0  14.2500       0.0
# 3             432.0       0.0  24.0    0.0    0.0   8.0500      -5.0

# %%
df[cat_columns].groupby(['Embarked']).count()
# Out:
#           Name  Sex  Ticket  Cabin  new_col
# Embarked
# C          168  168     168     69      168
# Q           77   77      77      4       77
# S          644  644     644    129      644
