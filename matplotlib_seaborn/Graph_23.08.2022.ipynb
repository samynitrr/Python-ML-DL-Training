# %%
import pandas as pd

# %%
df= pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# figure size manipulation

df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# bar graph
df.iloc[5:11].plot(kind='bar', figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[5]].plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[5]].plot(kind='barh', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(20,10), color='r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# pie chart
df1 = df.drop('species', axis=1)
df1.iloc[0].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# outliers - boxplot
df.plot(kind='box', figsize=(20,10),vert=False )
# Out:
# <AxesSubplot:>

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.plot.scatter(x='sepal_length', y='petal_length', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df2 = pd.read_csv('Test-data.txt', sep=',')
df2
# Out:
#                                                Point  Fanout  Cap  Trans  \
# 0                       clock SYS_2x_CLK (rise edge)     NaN  NaN    NaN
# 1                        clock network delay (ideal)     NaN  NaN    NaN
# 2  Karnataka/Bangalore/Sarjapurr_i/tercnt_n_reg_r...     0.2  0.0  0.20r
#
#    Incr  Path
# 0   0.0    0.0
# 1   0.2    0.2
# 2   NaN    NaN

# %%
df2[['point1', 'point2', 'point3', 'point4', 'point5']] = df2['Point'].str.split('/', expand=True)
df2
# Out:
#                                                Point  Fanout  Cap  Trans  \
# 0                       clock SYS_2x_CLK (rise edge)     NaN  NaN    NaN
# 1                        clock network delay (ideal)     NaN  NaN    NaN
# 2  Karnataka/Bangalore/Sarjapurr_i/tercnt_n_reg_r...     0.2  0.0  0.20r
#
#    Incr  Path                         point1     point2       point3  \
# 0   0.0    0.0  clock SYS_2x_CLK (rise edge)       None         None
# 1   0.2    0.2   clock network delay (ideal)       None         None
# 2   NaN    NaN                     Karnataka  Bangalore  Sarjapurr_i
#
#              point4             point5
# 0              None               None
# 1              None               None
# 2  tercnt_n_reg_reg  CLK (DFFARX1_HVT)

# %%
df2.to_excel('test_data.xlsx', index=False)
